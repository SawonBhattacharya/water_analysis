# %%
import pandas as pd

# %%
df=pd.read_csv('raw_data.csv')

# %%
df.head()
# Out:
#   District Block      Gram Panchayat  Village    Habitation New Location  \
# 0  PURULIA  PARA  JABARRAH JHAPRA-II  RANIPUR       RANIPUR           NO
# 1  PURULIA  PARA  JABARRAH JHAPRA-II  RANIPUR       RANIPUR           NO
# 2  PURULIA  PARA  JABARRAH JHAPRA-II  BAGALIA    SUKHSENDIH           NO
# 3  PURULIA  PARA  JABARRAH JHAPRA-II  BAGALIA  DURGASINGDIH           NO
# 4  PURULIA  PARA  JABARRAH JHAPRA-II  BAGALIA  DURGASINGDIH           NO
#
#   PWS Scheme Code PWS Scheme Name   Latitude  Longitude  Sample Id  \
# 0             NaN             NaN  23.473843  86.549878    2011777
# 1             NaN             NaN  23.472179  86.550049    2011776
# 2             NaN             NaN  23.434109  86.526807    2011768
# 3             NaN             NaN  23.433336  86.538334    2011775
# 4             NaN             NaN  23.433593  86.540368    2011773
#
#    Fluoride (mg/l)in TW water sample   \
# 0                                1.03
# 1                                0.87
# ...

# %%
df.describe()
# Out:
#            Latitude     Longitude     Sample Id  \
# count  31829.000000  31829.000000  3.182900e+04
# mean      23.302310     86.411950  1.207080e+06
# std        0.275191      0.735353  7.518451e+05
# min        0.000000      0.000000  2.800010e+05
# 25%       23.162622     86.213677  3.114150e+05
# 50%       23.328944     86.469924  1.041998e+06
# 75%       23.454851     86.633482  2.040198e+06
# max       23.684258     86.903520  2.081625e+06
#
#        Fluoride (mg/l)in TW water sample   \
# count                        21820.000000
# mean                             0.485946
# std                              0.369973
# min                              0.000000
# 25%                              0.260000
# 50%                              0.400000
# 75%                              0.610000
# max                              7.980000
#
#        Total Coliform (CFU/100ml) in TW water sample
# count                                    31829.000000
# ...

# %%
#important columns
#Habitation,Fluoride (mg/l)in TW water sample,Total Coliform (CFU/100ml) in TW water sample
#Village,Gram Panchayat,Block,District

#TW analysis
#find the threshold from net-> create a new column to use flag use area is less vulnerable and which is more vulnerable
#group the habitations and find the village with most no of vulnerable habitations
#do same for gram panchayat and block and district
#create four bar charts  of top 5 vulnerable villages,top 5 gram panchayat, Block, District

#PWS Scheme analysis
#find how many gram panchayats have the PWS scheme and make a pie chart on overall percentage
#check which district and block is having the highest no of gram panchayat with PWS scheme
